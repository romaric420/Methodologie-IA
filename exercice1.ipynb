# %%
import matplotlib.pyplot as plt
import seaborn as sns   
import pandas as pd

# %%
df = sns.load_dataset('healthexp')
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df['Country'].value_counts()
# Out:
# Country
# USA              51
# Japan            51
# Germany          50
# Canada           44
# Great Britain    43
# France           35
# Name: count, dtype: int64

# %%
df['Country'].value_counts().plot(kind='bar',rot=45)
plt.title("nombre dapparitions de chaque pays entre 1970 et 2020")
plt.show()

# %%
sns.countplot(data=df,x="Country")
plt.show()

# %%
df["Spending_USD"].describe()
# Out:
# count      274.000000
# mean      2789.338905
# std       2194.939785
# min        123.993000
# 25%       1038.357000
# 50%       2295.578000
# 75%       4055.610000
# max      11859.179000
# Name: Spending_USD, dtype: float64

# %%
df["Life_Expectancy"].plot(kind='hist', bins=20)
plt.show()

# %%
sns.boxplot(data=df,y='Spending_USD')
plt.show()

# %%
sns.histplot(data=df,x='Spending_USD')
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Count'>

# %%
df["Life_Expectancy"].describe()
# Out:
# count    274.000000
# mean      77.909489
# std        3.276263
# min       70.600000
# 25%       75.525000
# 50%       78.100000
# 75%       80.575000
# max       84.700000
# Name: Life_Expectancy, dtype: float64

# %%
df["Life_Expectancy"].plot(kind='hist', bins=20)
plt.show()

# %%
sns.histplot(data=df,x='Life_Expectancy')
# Out:
# <Axes: xlabel='Life_Expectancy', ylabel='Count'>

# %%
sns.boxplot(data=df,x='Spending_USD')
# Out:
# <Axes: xlabel='Spending_USD'>

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df.groupby("Year")["Life_Expectancy"].mean().plot(kind="bar")
plt.show()

# %%
sns.scatterplot(data=df,x="Year",y="Life_Expectancy",hue="Country")
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
df.groupby("Year")["Life_Expectancy"].describe()
# Out:
#       count       mean       std   min     25%    50%     75%   max
# Year
# 1970    5.0  71.520000  0.719027  70.6  70.900  71.90  72.000  72.2
# 1971    5.0  71.920000  0.936483  70.8  71.200  71.90  72.800  72.9
# 1972    3.0  71.800000  1.216553  71.0  71.100  71.20  72.200  73.2
# 1973    3.0  72.033333  1.184624  71.3  71.350  71.40  72.400  73.4
# 1974    3.0  72.400000  1.153256  71.5  71.750  72.00  72.850  73.7
# 1975    4.0  72.850000  1.190238  71.4  72.375  72.85  73.325  74.3
# 1976    4.0  73.325000  1.278997  71.8  72.625  73.35  74.050  74.8
# 1977    3.0  73.700000  1.442221  72.5  72.900  73.30  74.300  75.3
# 1978    3.0  73.866667  1.680278  72.4  72.950  73.50  74.600  75.7
# 1979    4.0  74.500000  1.471960  72.8  73.625  74.50  75.375  76.2
# 1980    6.0  74.233333  1.229092  72.9  73.325  74.00  74.975  76.1
# 1981    5.0  74.620000  1.347961  73.2  73.800  74.10  75.500  76.5
# 1982    5.0  74.920000  1.346105  73.5  74.100  74.50  75.600  76.9
# ...

# %%
sns.boxplot(data=df,x="Year",y="Life_Expectancy")
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df_filtered = df[df['Country'].isin(['Germany', 'Great Britain'])]
result = df_filtered.groupby(['Country', 'Year'])['Spending_USD'].mean()
print(result)
# Out:
# Country        Year
# Germany        1970     252.311
#                1971     298.251
#                1972     337.364
#                1973     384.541
#                1974     452.744
#                          ...
# Great Britain  2016    3960.141
#                2017    4059.125
#                2018    4189.708
#                2019    4385.463
#                2020    5018.700
# Name: Spending_USD, Length: 93, dtype: float64

# %%
sns.boxplot(data=df,x=result)
plt.show()

# %%
sns.scatterplot(
    data=df.query("(`Country` == 'Germany') | (`Country` == 'Great Britain')"),
    x="Spending_USD",
    y="Life_Expectancy"
)
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Life_Expectancy'>

# %%
#8
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.boxplot(data=df, x="Country", y="Life_Expectancy")
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.displot(data=df, x="Life_Expectancy", hue="Country")

# %%
df.groupby('Country')['Life_Expectancy'].plot(kind='hist')
plt.show()

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
plt.scatter(df['Spending_USD'], df['Life_Expectancy'])
plt.show()

# %%
sns.scatterplot(data=df, x='Spending_USD', y='Life_Expectancy')
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Life_Expectancy'>

# %% [markdown]
# # 9 derniere question

# %%
df.query("`Country` == 'USA' & `Year` >= 2000")
# Out:
#      Year Country  Spending_USD  Life_Expectancy
# 153  2000     USA      4536.561             76.7
# 159  2001     USA      4888.518             76.9
# 165  2002     USA      5316.522             77.0
# 171  2003     USA      5726.538             77.1
# 177  2004     USA      6069.530             77.6
# 183  2005     USA      6430.757             77.6
# 189  2006     USA      6808.054             77.8
# 195  2007     USA      7166.513             78.1
# 201  2008     USA      7385.026             78.1
# 207  2009     USA      7645.002             78.5
# 213  2010     USA      7879.253             78.6
# 219  2011     USA      8079.467             78.7
# 225  2012     USA      8346.064             78.8
# 231  2013     USA      8519.620             78.8
# 237  2014     USA      8925.879             78.9
# 243  2015     USA      9355.118             78.7
# 249  2016     USA      9717.649             78.7
# 255  2017     USA     10046.472             78.6
# ...

# %%
sns.scatterplot(data=df.query("`Country` == 'USA' & `Year`>=2000"),x="Spending_USD",y="Life_Expectancy")
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Life_Expectancy'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df.query("`Country` == 'USA' & `Year`>=2000"), 
                x="Spending_USD", y="Life_Expectancy")


df_filtered = df.query("`Country` == 'USA' & `Year`>=2000")


for idx, row in df_filtered.iterrows():
    plt.text(row['Spending_USD'], row['Life_Expectancy'], 
             str(int(row['Year'])),  
             fontsize=9, 
             ha='center',  
             va='bottom')  

plt.show()
