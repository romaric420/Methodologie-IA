# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn.feature_selection import SelectKBest,f_regression
from sklearn.datasets import make_regression

# %%
x ,y = make_regression(n_samples=100,n_features=3,random_state=7)


fig , ax = plt.subplots(1,3 , figsize=(16,3))
for i in range(3):
    ax[i].scatter(x[:,1],y)
    ax[i].set_xlabel(f"x[{i})")
    ax[i].set_ylabel("y")
plt.show()

# %%
feature_selector = SelectKBest(score_func=f_regression,k=2)
feature_selector.fit(x,y)
# Out:
# SelectKBest(k=2, score_func=<function f_regression at 0x7f9e9d422f20>)

# %%
feature_selector.get_feature_names_out()
# Out:
# array(['x0', 'x2'], dtype=object)
